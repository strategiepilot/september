# %%
import pandas as pd
import datetime

from facebook_scraper import get_posts

# %%
settings = {"comments": True, "posts_per_page": 100}

# %%
for post in get_posts(group="204754483765976", options=settings):
    print("="*100)
    print(post['text'][:50])

# %%
POSTS = get_posts('deutschetelekom', pages=100, options=settings)

# %%
p1 = {'available': True,
 'comments': 459,
 'comments_full': None,
 'factcheck': None,
 'fetched_time': datetime.datetime(2021, 4, 20, 13, 39, 53, 651417),
 'image': 'https://scontent.fhlz2-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/58745049_2257182057699568_1761478225390731264_n.jpg?_nc_cat=111&ccb=1-3&_nc_sid=8024bb&_nc_ohc=ygH2fPmfQpAAX92ABYY&_nc_ht=scontent.fhlz2-1.fna&tp=14&oh=7a8a7b4904deb55ec696ae255fff97dd&oe=60A36717',
 'images': ['https://scontent.fhlz2-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/58745049_2257182057699568_1761478225390731264_n.jpg?_nc_cat=111&ccb=1-3&_nc_sid=8024bb&_nc_ohc=ygH2fPmfQpAAX92ABYY&_nc_ht=scontent.fhlz2-1.fna&tp=14&oh=7a8a7b4904deb55ec696ae255fff97dd&oe=60A36717'],
 'is_live': False,
 'likes': 3509,
 'link': 'https://www.nintendo.com/amiibo/line-up/',
 'post_id': '2257188721032235',
 'post_text': 'Don’t let this diminutive version of the Hero of Time fool you, '
              'Young Link is just as heroic as his fully grown version! Young '
              'Link joins the Super Smash Bros. series of amiibo figures!\n'
              '\n'
              'https://www.nintendo.com/amiibo/line-up/',
 'post_url': 'https://facebook.com/story.php?story_fbid=2257188721032235&id=119240841493711',
 'reactions': {'haha': 22, 'like': 2657, 'love': 706, 'sorry': 1, 'wow': 123}, # if `extra_info` was set
 'reactors': None,
 'shared_post_id': None,
 'shared_post_url': None,
 'shared_text': '',
 'shared_time': None,
 'shared_user_id': None,
 'shared_username': None,
 'shares': 441,
 'text': 'Don’t let this diminutive version of the Hero of Time fool you, '
         'Young Link is just as heroic as his fully grown version! Young Link '
         'joins the Super Smash Bros. series of amiibo figures!\n'
         '\n'
         'https://www.nintendo.com/amiibo/line-up/',
 'time': datetime.datetime(2019, 4, 30, 5, 0, 1),
 'user_id': '119240841493711',
 'username': 'Nintendo',
 'video': None,
 'video_id': None,
 'video_thumbnail': None,
 'w3_fb_url': 'https://www.facebook.com/Nintendo/posts/2257188721032235'}

# %%
df = pd.DataFrame.from_dict(p1, orient="index").T
df.head()

# %%
len(dfListe)

# %%
df = pd.concat(dfListe)
df.set_index("post_id", inplace=True)
df.head()
# Out:
#                                                                 text  \
# post_id
# 10159241409418555  SOS-Knopf und automatische Sturzerkennung – sc...
# 477094526737966    TUE, JUL 6 AT 10:00 AM UTC+02 AND 9 MORE\nTele...
# 948826725868636    TUE, JUN 15 AT 10:00 AM UTC+02 AND 4 MORE\nTel...
# 10159241284818555  Was bringt die Zukunft? Welcher Job passt zu m...
# 348755453340943    WED, MAY 19 AT 7:00 PM UTC+02\nDigitale Inform...
#
#                                                            post_text  \
# post_id
# 10159241409418555  SOS-Knopf und automatische Sturzerkennung – sc...
# 477094526737966
# 948826725868636
# 10159241284818555  Was bringt die Zukunft? Welcher Job passt zu m...
# 348755453340943
#
#                                                          shared_text  \
# post_id
# 10159241409418555
# 477094526737966    TUE, JUL 6 AT 10:00 AM UTC+02 AND 9 MORE\nTele...
# 948826725868636    TUE, JUN 15 AT 10:00 AM UTC+02 AND 4 MORE\nTel...
# 10159241284818555
# 348755453340943    WED, MAY 19 AT 7:00 PM UTC+02\nDigitale Inform...
#
#                                  time image  \
# post_id
# 10159241409418555 2021-05-19 12:04:46  None
# 477094526737966   2021-05-19 11:13:08  None
# 948826725868636   2021-05-19 11:05:21  None
# 10159241284818555 2021-05-19 10:13:16  None
# 348755453340943   2021-05-19 07:22:00  None
#
#                                                     image_lowquality images  \
# post_id
# 10159241409418555                                               None     []
# 477094526737966    https://external.fmuc4-1.fna.fbcdn.net/safe_im...     []
# 948826725868636    https://external.fmuc4-1.fna.fbcdn.net/safe_im...     []
# 10159241284818555                                               None     []
# 348755453340943    https://external.fmuc4-1.fna.fbcdn.net/safe_im...     []
#
#                                                    images_lowquality  \
# post_id
# 10159241409418555                                                 []
# 477094526737966    [https://external.fmuc4-1.fna.fbcdn.net/safe_i...
# 948826725868636    [https://external.fmuc4-1.fna.fbcdn.net/safe_i...
# 10159241284818555                                                 []
# 348755453340943    [https://external.fmuc4-1.fna.fbcdn.net/safe_i...
#
#                                                                video  \
# post_id
# 10159241409418555  https://video.fmuc4-1.fna.fbcdn.net/v/t42.1790...
# 477094526737966                                                 None
# 948826725868636                                                 None
# 10159241284818555  https://video.fmuc4-1.fna.fbcdn.net/v/t42.1790...
# 348755453340943                                                 None
#
#                                                      video_thumbnail  ...  \
# post_id                                                               ...
# 10159241409418555  https://scontent.fmuc4-1.fna.fbcdn.net/v/t15.5...  ...
# 477094526737966                                                 None  ...
# 948826725868636                                                 None  ...
# 10159241284818555  https://scontent.fmuc4-1.fna.fbcdn.net/v/t15.5...  ...
# 348755453340943                                                 None  ...
#
#                   factcheck shared_post_id shared_time shared_user_id  \
# post_id
# 10159241409418555      None           None        None           None
# 477094526737966        None           None        None           None
# 948826725868636        None           None        None           None
# 10159241284818555      None           None        None           None
# 348755453340943        None           None        None           None
#
#                   shared_username shared_post_url available comments_full  \
# post_id
# 10159241409418555            None            None      True          None
# 477094526737966              None            None      True            []
# 948826725868636              None            None      True            []
# 10159241284818555            None            None      True          None
# 348755453340943              None            None      True            []
#
#                   reactors w3_fb_url
# post_id
# 10159241409418555     None      None
# 477094526737966       None      None
# 948826725868636       None      None
# 10159241284818555     None      None
# 348755453340943       None      None
#
# [5 rows x 30 columns]

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1902 entries, 10159241409418555 to 1491075920985721
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               1902 non-null   object
#  1   post_text          1902 non-null   object
#  2   shared_text        1902 non-null   object
#  3   time               1902 non-null   datetime64[ns]
#  4   image              274 non-null    object
#  5   image_lowquality   1078 non-null   object
#  6   images             1902 non-null   object
#  7   images_lowquality  1902 non-null   object
#  8   video              797 non-null    object
#  9   video_thumbnail    797 non-null    object
#  10  video_id           797 non-null    object
#  11  likes              1902 non-null   object
#  12  comments           1902 non-null   object
#  13  shares             1902 non-null   object
#  14  post_url           1902 non-null   object
#  15  link               1015 non-null   object
#  16  user_id            1894 non-null   object
#  17  username           1902 non-null   object
#  18  user_url           1902 non-null   object
#  19  is_live            1902 non-null   object
#  20  factcheck          0 non-null      object
#  21  shared_post_id     53 non-null     object
#  22  shared_time        53 non-null     object
#  23  shared_user_id     53 non-null     object
#  24  shared_username    53 non-null     object
#  25  shared_post_url    53 non-null     object
#  26  available          1902 non-null   object
#  27  comments_full      273 non-null    object
#  28  reactors           0 non-null      object
#  29  w3_fb_url          0 non-null      object
# dtypes: datetime64[ns](1), object(29)
# memory usage: 525.2+ KB

# %%
df.comments.hist(bins=200)
# Out:
# <AxesSubplot:>

# %%
df.loc[df.comments==80,"comments_full"]
# Out:
# post_id
# 1409002492787873    [{'comment_id': '1412119272476195', 'commenter...
# Name: comments_full, dtype: object

# %%
df.comments_full["297776751380026"]

df.comments_full["1409002492787873"]

# 1409002492787873
# Out:
# [{'comment_id': '1412119272476195',
#   'commenter_url': None,
#   'commenter_name': 'Udo Weidner',
#   'commenter_meta': None,
#   'comment_text': 'Ich wollte von meinem Hauptverteilerk\nasten wo Glasfaser anliegt bis zu mir ins Grundstück Glasfaser verlegt haben. Bis jetzt ist da das alte Kupferkabel drin. Leerrohre sind im Fußweg ebenso bis zu mir ins Haus. Entfernung sind etwa 70 m. Und nun der Hammer, Telekom möchte dafür sage und schreibe 34000 Euro haben. Ich dachte ich fall vom Glauben ab. Naja Internet der Zukunft hat eben seinen Preis.....',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412151955806260',
#   'commenter_url': None,
#   'commenter_name': 'Uwe Neinger',
#   'commenter_meta': None,
#   'comment_text': 'seht zu das das Netz stabil bleibt und verbastelt nicht wieder alles !!! es kann nicht sein das man beim Telefonieren laufend unterbrochen wird nur weil das Netz laufend zusammenbricht',
#   'comment_time': None},
#  {'comment_id': '1412041335817322',
#   'commenter_url': None,
#   'commenter_name': 'Sascha Hörr',
#   'commenter_meta': None,
#   'comment_text': 'Ihr seid ein geiler Laden!\nEs ist toll in Deutschland solche Unternehmen haben zu können',
#   'comment_time': None},
#  {'comment_id': '1412056389149150',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'In Berlin-Mariendo\nrf Kitzingstr. kein DSL 😜',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412083679146421',
#   'commenter_url': None,
#   'commenter_name': 'Herbert Arnhaeuser',
#   'commenter_meta': None,
#   'comment_text': 'Die Telekom soll erst einmal schauen das man überall normalen Empfang mit Handy hat, in meinem Wohnort geht mit Telekom nichts und weigern sicch noch einem aus dem Vertrag zu lassen obwohl man keinen Empfang hat.',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412025459152243',
#   'commenter_url': None,
#   'commenter_name': 'Uwe Fuellenbach',
#   'commenter_meta': None,
#   'comment_text': 'Tolle Präsentation! Aber das hilft meinen Nachbarn und mir überhaupt nicht. Wir müssen uns mit 6 MBit/s begnügen und es gibt keinerlei Ausbaupläne der Telekom. Die andere Strassenseite bekommt 250 MBit/s.',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412089882479134',
#   'commenter_url': None,
#   'commenter_name': 'John Olford',
#   'commenter_meta': None,
#   'comment_text': 'Ich kann es nur empfehlen die Finger von 5G weg zu lassen. Es ist eine Lösung auf die Suche nach ein Problem und gesundheitliche\nsehr bedenklich.',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412095289145260',
#   'commenter_url': None,
#   'commenter_name': 'Alice Kurebayashi',
#   'commenter_meta': None,
#   'comment_text': 'haha telekom 😂erstmal flächendeckend ausbauen bevor man neues ausprobiert , wäre mal schön',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412087162479406',
#   'commenter_url': None,
#   'commenter_name': 'Per Pampus',
#   'commenter_meta': None,
#   'comment_text': 'Lächerlich kein Flächendeckende\ns DSL mit minimum 50MBit, Kein Fächendeckender\nHandyempfang etc. Die Telekom hat alles verschlafen ausser die Preise zu erhöhen für die Leistung',
#   'comment_time': None},
#  {'comment_id': '1412015159153273',
#   'commenter_url': None,
#   'commenter_name': 'Nasko Tafa',
#   'commenter_meta': None,
#   'comment_text': 'Gibt es evt. ein Link auf Youtube?',
#   'comment_time': None},
#  {'comment_id': '1412016595819796',
#   'commenter_url': None,
#   'commenter_name': 'Ernst Sicken',
#   'commenter_meta': None,
#   'comment_text': 'Leider erfolgt der Ausbau nur in dicht besiedelten Regionen und auf dem Land passiert nichts',
#   'comment_time': None},
#  {'comment_id': '1412070002481122',
#   'commenter_url': None,
#   'commenter_name': 'Peter Ehrlich',
#   'commenter_meta': None,
#   'comment_text': 'Hilft nix wenn der nächste Sendemast 1,4km weg ist und durch nen Wäldchen muss. Hier gibt outddor nichtmal 1,8 GHz 4G ... Mit Richantenne auf dem Dachboden hab ich gestanden um nen Signal bei 4G zu haben ;-)',
#   'comment_time': None},
#  {'comment_id': '1412020895819366',
#   'commenter_url': None,
#   'commenter_name': 'Ulrich Si',
#   'commenter_meta': None,
#   'comment_text': '250 Mbit ? Bei mir sind neuerdings nur 175 Mbit verfügbar! Seit 3 Jahren Registriert für Glasfaser aber das Interessiert niemand man baut lieber Neubaugebiete aus.',
#   'comment_time': None},
#  {'comment_id': '1412088869145902',
#   'commenter_url': None,
#   'commenter_name': 'Reiner Grube',
#   'commenter_meta': None,
#   'comment_text': '5 G ? Ich lach mich schlapp ,wir wären schon froh wenn wir überhaupt mal einen vernünftigen Empfang bekommen würden',
#   'comment_time': None},
#  {'comment_id': '1412102785811177',
#   'commenter_url': None,
#   'commenter_name': 'Andy Langner',
#   'commenter_meta': None,
#   'comment_text': 'LOL, ein Dank dafür das die Telekom viele Firmen einfach gekappt haben und es denen einfach egal ist..... Das dort Arbeitsplätze drann hängen .... Und man nie eine richtige Antwort bekommt warum man einfach gekappt wurde ... ?!',
#   'comment_time': None},
#  {'comment_id': '1412024492485673',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'Netzausbau in NL ist keine Herausforderung\n. Komplett flach 😜',
#   'comment_time': None},
#  {'comment_id': '1412040645817391',
#   'commenter_url': None,
#   'commenter_name': 'Karanjyot Singh Bhatia',
#   'commenter_meta': None,
#   'comment_text': 'Wo sind die neuen Mobilfunktarife\n?🤷🏻\u200d♂️',
#   'comment_time': None},
#  {'comment_id': '1412021535819302',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'Freitag wird meine Telekom SIM Karte aktiviert und meine Nummer Portiert. Bin gespannt 🤩',
#   'comment_time': None},
#  {'comment_id': '1412067599148029',
#   'commenter_url': None,
#   'commenter_name': 'Peter Ehrlich',
#   'commenter_meta': None,
#   'comment_text': '3,6 GHz - Ein gut belaubter Baum und das wars mit dem Signal ... 1,8 GHz schafft es wenigstens noch durch eine Wand wenn die Station max. 300 Meter weg steht ...',
#   'comment_time': None,
#   'replies': []},
#  {'comment_id': '1412021975819258',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'Wenn man weiß wo T-Mobile herkommt weiß man warum der Netzausbau so gut ist.',
#   'comment_time': None},
#  {'comment_id': '1412023105819145',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'Stellt euch mal vor E-Plus hätte die DFMG gehabt 🤪',
#   'comment_time': None},
#  {'comment_id': '1412025782485544',
#   'commenter_url': None,
#   'commenter_name': 'Sarah Held',
#   'commenter_meta': None,
#   'comment_text': 'Ich mag auch mitspielen. Aber wir wohnen zu "idyllisch". #landleben #wirhabenheutele\niderkeinInterne\ntfürdich',
#   'comment_time': None},
#  {'comment_id': '1412088139145975',
#   'commenter_url': None,
#   'commenter_name': 'Peter Ehrlich',
#   'commenter_meta': None,
#   'comment_text': 'Peering immer schön den Daumen in die Wunde ;-)',
#   'comment_time': None},
#  {'comment_id': '1412029329151856',
#   'commenter_url': None,
#   'commenter_name': 'Peter Ehrlich',
#   'commenter_meta': None,
#   'comment_text': 'Also von ADSL 6 MBit direkt auf FTTH ... na das wird spannend',
#   'comment_time': None},
#  {'comment_id': '1412093212478801',
#   'commenter_url': None,
#   'commenter_name': 'Da Ni',
#   'commenter_meta': None,
#   'comment_text': 'Glas Faser im Haus und nur 50 Mbit 🤣',
#   'comment_time': None},
#  {'comment_id': '1412086639146125',
#   'commenter_url': None,
#   'commenter_name': 'Björn Otto',
#   'commenter_meta': None,
#   'comment_text': 'Wichtig wann gibt es neu Tarif Dsl Vdsl FTTH 5g',
#   'comment_time': None},
#  {'comment_id': '1412032712484851',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'Die denken in den Schulen „ging doch früher auch“',
#   'comment_time': None},
#  {'comment_id': '1412041892483933',
#   'commenter_url': None,
#   'commenter_name': 'Peter Ehrlich',
#   'commenter_meta': None,
#   'comment_text': 'FTTH Tarife wurden erst neu verschlechtert und der Privatkundentar\nif für 1000/500 FTTH abgeschafft ...',
#   'comment_time': None},
#  {'comment_id': '1412064062481716',
#   'commenter_url': None,
#   'commenter_name': 'Robert Walter',
#   'commenter_meta': None,
#   'comment_text': 'Gibt es eine Netzkarte wo man DSS ausblenden kann. 😊',
#   'comment_time': None},
#  {'comment_id': '1412041195817336',
#   'commenter_url': None,
#   'commenter_name': 'Björn Otto',
#   'commenter_meta': None,
#   'comment_text': 'gibt es irgenwann mal neu FTTH tarife wenn ja wann kommen die ??',
#   'comment_time': None}]

# %%
df.to_pickle("TelekomFacebookPosts_19-05-2021.pkl")

# %%
df.comments = df.comments.astype("int")

# %%
df.comments.value_counts()
# Out:
# 0      254
# 2      186
# 1      181
# 3      129
# 7       90
#       ...
# 111      1
# 112      1
# 114      1
# 131      1
# 854      1
# Name: comments, Length: 136, dtype: int64

# %%
df.loc[df.comments==99, ["comments", "comments_full"]]
# Out:
#                  comments                                      comments_full
# post_id
# 297776751380026        99  [{'comment_id': '298481077976260', 'commenter_...

# %%
df.loc[297776751380026,"comments_full"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 297776751380026
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-837d24006bfa> in <module>
# ----> 1 df.loc[297776751380026,"comments_full"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3736                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3737         else:
# -> 3738             loc = index.get_loc(key)
#    3739
#    3740             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 297776751380026

# %%
df.comments_full.sample(20)
# Out:
# post_id
# 10157606165273555                                                 None
# 10158244096313555                                                 None
# 10156080745198555                                                 None
# 10156554364513555                                                 None
# 10158840143143555    [{'comment_id': '10158843630498555', 'commente...
# 10155912926413555                                                 None
# 10156748892158555                                                 None
# 10158656265923555                                                 None
# 10158133991888555    [{'comment_id': '10158134016163555', 'commente...
# 10156535619128555                                                 None
# 10158477206043555                                                 None
# 10156564987078555                                                 None
# 10156753316823555                                                 None
# 10157738618283555                                                 None
# 10156535231153555                                                 None
# 10158937005283555    [{'comment_id': '10158937045788555', 'commente...
# 10157076942958555                                                 None
# 10157537968313555                                                 None
# 10156782954778555                                                 None
# 10157075434073555                                                 None
# Name: comments_full, dtype: object

# %%
import pandas as pd
import datetime
from facebook_scraper import get_posts

settings = {"comments": True, "posts_per_page": 100}
dfListe = []

for post in get_posts('deutschetelekom', pages=20, options=settings):
    print("="*100)
    print(post['text'][:200])
    df = pd.DataFrame.from_dict(post, orient="index").T
    dfListe.append(df)
# Out:
# =============
# Interessante Tipps und Infos für Eltern: Für die neue Folge der Netzgeschichten wirft Moderator Christian einen Blick ins digitale Kinderzimmer. ^andreas
# ====================================================================================================
# Wir zeigen alle WM-Qualifikationsspiele der Deutscher Basketball Bund Herren live und kostenlos im Fernsehen, im Web und per App bei Telekom Sport ! Los geht’s mit dem Spiel gegen Georgien morgen am 2
# ====================================================================================================
# Der Breitbandausbau der Telekom läuft auf Hochtouren. Insgesamt misst unser Glasfasernetz inzwischen satte 455.000 Kilometer - das ist Rekord! bit.ly/2hLQYpR ^karim
# ====================================================================================================
# Im Telekom-Blog "Netz" bündeln wir einmal pro Woche die wichtigsten Ausbaumeldungen http://bit.ly/2zu562j !
# ====================================================================================================
# Rettung mit dem besten Netz! Mit Hilfe der bestehenden Mobilfunknetze lassen sich Drohnen sicher in den Luftraum integrieren. Gemeinsam mit der DFS Deutsche Flugsicherung haben wir dies im Rahmen eine
# ====================================================================================================
# Wir forcieren den Breitbandausbau in Deutschland. Alleine in diesem Jahr kommen 40.000 km Glasfaser dazu. Kleinere Städte profitieren von einem neuen Vermarktungsansatz bei FTTH. ^karim
#
# TELEKOM.COM
# G
# ====================================================================================================
# Heute ist Welttag des Fernsehens! Trotz Social Media und Smartphones liebt die Welt weiterhin TV. Und wir übrigens auch: Alleine in Europa bedienen wir über 4,2 Millionen TV-Kunden. Euch viel Spaß bei
# ====================================================================================================
# Die Mobilität der Zukunft ist autonom, smart und vernetzt. Darin waren sich alle einig beim vergangenen Telekom Museumstalks im Mercedes-Benz Museum. Neben technologischen und ethischen Aspekten ging
# ====================================================================================================
# WED, DEC 20, 2017
# Netzausbau Infoveranstaltung Telekom in Rosenberg OT Bronnacker
# ====================================================================================================
# TUE, DEC 19, 2017
# Netzausbau Infoveranstaltung Telekom in Rosenberg OT Rosenberg
# ====================================================================================================
# TUE, DEC 12, 2017
# Telekom Netzausbau Infoveranstaltung in Adelsheim
# ====================================================================================================
# THU, DEC 7, 2017
# Telekom Infoveranstaltung Netzausbau in Limbach
# ====================================================================================================
# TUE, DEC 5, 2017
# Infoveranstaltung Netzausbau in Seckach
# ====================================================================================================
# "Hallo Magenta!" - Ab nächstem Jahr hört das Zuhause aufs Wort. Mit unserem neuen Smart Speaker mit eigener Sprachsteuerung können die Telekom Services dann auf Zuruf gesteuert werden. Dank einer Verb
# ====================================================================================================
# WED, NOV 29, 2017
# Beraterbus in Wetter
# ====================================================================================================
# WED, NOV 29, 2017
# Bürgerinformationsveranstaltung Kürten
# ====================================================================================================
# WED, NOV 15, 2017
# Infoveranstaltung Vermarktungsstart Netzausbau in Riedlingen
# ====================================================================================================
# MON, DEC 4, 2017
# Bürgerinfoveranstaltung Oberdiebach
# ====================================================================================================
# Kann Künstliche Intelligenz bald auch Chef sein? Darüber haben die Experten Hüseyin Özdemir und Alex Weidauer bei der telegraphen_lounge diskutiert. Was dabei herauskam, lest ihr im Blog.Telekom. ^and
# ====================================================================================================
# Rekordhoch! Wir haben in den ersten neuen Monaten in 2017 weltweit 9,2 Milliarden Euro unter anderem in den Netzausbau investiert. Unsere Zahl der Woche. ^thorben
# ====================================================================================================
# Werden unsere Multifunktionsgehäuse zukünftig als Tankstellen für Elektroautos genutzt? Telekom Chef Tim Höttges kann sich das durchaus vorstellen. Im Video resümiert er seinen Besuch auf dem automobi
# ====================================================================================================
# Auf hoher See für Highspeed-Internet im Flugzeug! Mit großen Booten und kleinen Schiffen geht's für den Netzausbau des European Aviation Networks zu den griechischen Inseln der Ägäis. di-ri.co/EirnK ^
# ====================================================================================================
# TUE, NOV 21, 2017
# Bürgerinfoveranstaltung Liebenburg
# ====================================================================================================
# Ohne Kommunikation läuft auf einer Konferenz mit 25.000 Teilnehmern genau was? - Ach ja, nichts! Damit die 25.000 Delegierten der UN-Klimakonferenz sich bestens vernetzen können, hat die Telekom zusät
# ====================================================================================================
# „Wir haben sehr, sehr starke Ergebnisse abgeliefert!" Die Telekom hat heute die Ergebnisse des dritten Quartals vorgestellt. Finanzvorstand Thomas Dannenfeldt fasst für Euch das wichtigste in unter 60
# ====================================================================================================
# THU, DEC 21, 2017
# Bürgerberatungstage Gerstungen
# ====================================================================================================
# SAT, NOV 18, 2017
# Bürgerberatungstage Schnelles Internet in Tambach-Dietharz
# ====================================================================================================
# TUE, NOV 14, 2017
# Bürgerinformationsveranstaltung zum Netzausbau in Goslar
# ====================================================================================================
# Im Telekom-Blog "Netz" bündeln wir einmal pro Woche die wichtigsten Ausbaumeldungen http://bit.ly/2m44GsQ !
# ====================================================================================================
# Der Versandhandel wird immer wichtiger. Dabei ist nicht nur für den Empfänger die Verfolgung der Sendungen praktisch. Dank Roambee, einem Start-Up und Telekom Partner, weiß der Empfänger immer in Echt
# ====================================================================================================
# THU, NOV 9, 2017
# Bürgerberatungstag Gerstungen
# ====================================================================================================
# THU, NOV 9, 2017
# Telegraphen_lounge Wann ersetzt KI das Management?
# ====================================================================================================
# TUE, DEC 5, 2017
# Bürgerinfoveranstaltung für Bösingen und Herrenzimmern
# ====================================================================================================
# FRI, NOV 17, 2017
# Museumstalk: Mobilität der Zukunft
# ====================================================================================================
